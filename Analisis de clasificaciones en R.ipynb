# %%
install.packages("SoilTaxonomy")
install.packages('data.tree')

library(SoilTaxonomy)
library(data.tree)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
getTaxonAtLevel('Oxiaquic Dystrudepts', level = "order")
# Out:
# Fluventic Haplustepts
#         "inceptisols"

# %%
getTaxonAtLevel('Oxic Dystrudepts', level = "suborder")
# Out:
# Oxic Dystrudepts
#         "udepts"

# %%
getTaxonAtLevel('Oxic Dystrudepts', level = "greatgroup")
# Out:
# Oxic Dystrudepts
#    "dystrudepts"

# %%
getTaxonAtLevel('Oxic Dystrudepts', level = "subgroup")
# Out:
#   Oxic Dystrudepts
# "oxic dystrudepts"

# %% [markdown]
# Ahora podemos ver las caracteristicas de esos niveles jerarquicos de clasifcación

# %%
cat(explainST('Typic Hemic Haplofibrist'))
# Out:
# typic hemic haplofibrist
#             |
#             minimum horizon development

# %% [markdown]
# Revisar posibles clasificaciones a nivel de subgrupo

# %%
taxonTree(c("Dystrudepts", "Haplustox", "Haplustepts", "Haplofibrists"))
# Out:
# Soil Taxonomy
#  |-histosols
#  |   |-fibrists
#  |       |-haplofibrists
#  |           |-hydric haplofibrists
#  |           |-lithic haplofibrists
#  |           |-limnic haplofibrists
#  |           |-terric haplofibrists
#  |           |-fluvaquentic haplofibrists
#  |           |-hemic haplofibrists
#  |           |-typic haplofibrists
#  |-oxisols
#  |   |-ustox
#  |       |-haplustox
#  |           |-aquic petroferric haplustox
#  |           |-petroferric haplustox
#  |           |-aquic lithic haplustox
#  |           |-lithic haplustox
#  |           |-plinthaquic haplustox
#  |           |-plinthic haplustox
#  |           |-aqueptic haplustox
#  |           |-aquic haplustox
#  |           |-oxyaquic haplustox
#  |           |-inceptic haplustox
#  |           |-humic rhodic haplustox
#  |           |-humic xanthic haplustox
#  |           |-humic haplustox
#  |           |-rhodic haplustox
#  |           |-xanthic haplustox
#  |           |-typic haplustox
# ...
